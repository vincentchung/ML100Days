# %%
import os
import numpy as np
import pandas as pd

dir_data="../home-credit-default-risk"
f_app = os.path.join(dir_data, 'application_train.csv')
print('Path of read in data: %s' % (f_app))
app_train = pd.read_csv(f_app)

app_train.head()

# standard deviation of AMT_ANNUITY
app_train["AMT_ANNUITY"].std()
# Out:
# Path of read in data: ../home-credit-default-risk/application_train.csv
# 14493.737315117392

# %%
import matplotlib.pyplot as plt
app_train["AMT_ANNUITY"].hist(bins=50, figsize=(20,15))
plt.show()
